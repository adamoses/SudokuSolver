# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sudoku1 = '009032000000700000162000000010020560000900000050000107000000403026009000005870000'
sudoku2 = '700500001000190040000000670090004000030000007000200580008000000052070009003800060'
sudoku3 = '030000000590000700004350000000090560000807042000004000006000000801000900040200801'
sudoku4 = '200004000704008000000000079006000300400206000051000006008400000000010607007080050'
sudoku5 = '600710002300000096800000005009000000000000429070800000000003050130007000020054000'


blank1 = sudoku1.count('0')
blank2 = sudoku2.count('0')
blank3 = sudoku3.count('0')
blank4 = sudoku4.count('0')
blank5 = sudoku5.count('0')

num_given = np.array([blank1, blank2, blank3, blank4, blank5])
num_given = 81 - num_given

csp_backtrack_time = [2.346, 0.516,5.347,8.049,1.866]
csp_backtrack_expansions = [1926,407,2459,3231,836]

csp_backtrack_human_time = [2.189,1.744,3.320,3.460,1.612]
csp_backtrack_human_expansions = [89,59,91,100,58]

dfs_time = [300.688,11.827,26.352,114.188,15.37]
dfs_expansions = [761374,27508,69155,329645,46345]

fig=plt.figure(figsize=(15,15))
ax=fig.add_subplot(111)

ax.plot(np.arange(1,6), csp_backtrack_time, 'ro', label='CSP Backtracking')
ax.plot(np.arange(1,6), csp_backtrack_human_time, 'go', label='CSP Backtracking with Human Technique Domain Reduction')
ax.plot(np.arange(1,6), dfs_time, 'bo', label='Informed DFS')

ax.legend(prop={'size': 20})
ax.set_yscale('log')
ax.tick_params(axis='y', labelsize=20, size=15)
ax.get_xaxis().set_ticks([])
ax.set_ylabel('Time [s]', fontsize=25)

fig.savefig('SolvingTime.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig=plt.figure(figsize=(15,15))
ax=fig.add_subplot(111)

ax.plot(np.arange(1,6), csp_backtrack_expansions, 'ro', label='CSP Backtracking')
ax.plot(np.arange(1,6), csp_backtrack_human_expansions, 'go', label='CSP Backtracking with Human Technique Domain Reduction')
ax.plot(np.arange(1,6), dfs_expansions, 'bo', label='Informed DFS')

ax.legend(prop={'size': 20})
ax.set_yscale('log')
ax.tick_params(axis='y', labelsize=20, size=15)
ax.get_xaxis().set_ticks([])
ax.set_ylabel('# of Expansions', fontsize=25)

ax.set_ylim(10, 10e6)

fig.savefig('SolvingExpansions.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
